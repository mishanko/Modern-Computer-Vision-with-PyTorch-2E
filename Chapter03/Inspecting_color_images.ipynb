# %% [markdown]
# <a href="https://colab.research.google.com/github/PacktPublishing/Modern-Computer-Vision-with-PyTorch-2E/blob/main/Chapter03/Inspecting_color_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2, matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread('IMG_4122-2.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
print(img.shape)
# Out:
# (1888, 1416, 3)

# %%
crop = img[-3:,-3:]
plt.imshow(crop)

# %%
crop
# Out:
# array([[[233, 225, 238],
#         [233, 225, 238],
#         [233, 225, 238]],
#
#        [[234, 226, 239],
#         [234, 226, 239],
#         [234, 226, 239]],
#
#        [[234, 226, 239],
#         [234, 226, 239],
#         [234, 226, 239]]], dtype=uint8)
